# %% [markdown]
# <a href="https://colab.research.google.com/github/Yadanar025/MMDT_T-PY101_Batch03/blob/main/Khin_Yadanar_Aung/Ex04_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
string = input("Enter a string")
i = 0
while i<len(string):
  print(string[i])
  i+=1
# Out:
# Enter a stringhello
# h
# e
# l
# l
# o

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight = int(input("Enter Weight"))
while (weight<0):
  weight = int(input("The weight is under 0, enter the weight above 0"))
# Out:
# Enter Weight-10
# The weight is under 0, enter the weight above 0-5
# The weight is under 0, enter the weight above 0-1
# The weight is under 0, enter the weight above 010

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
count = -1
total_score = 0
#number = 1
test_score=1
countA = 0
while (test_score>0):
  test_score = int(input("Enter a test score "))
  total_score = total_score+test_score
  count +=1
  if (test_score>=90):
    countA = countA+1
  print("Enter a negative number to finish")

print(f"The average test score is {(total_score+1)/count}")
print(f"The total A's (90 or above) is {countA}")
# Out:
# Enter a test score 90
# Enter a negative number to finish
# Enter a test score 91
# Enter a negative number to finish
# Enter a test score 90
# Enter a negative number to finish
# Enter a test score 91
# Enter a negative number to finish
# Enter a test score -1
# Enter a negative number to finish
# The average test score is 90.5
# The total A's (90 or above) is 4

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
string = input("Enter a string ")
letter = input("Enter a letter ")
i=0
for let in string:
  if string[i] ==letter:
    print(f"The string {string} contain a letter {letter} and the index is {i}")
    break
  i+=1
else :
  print(f"The string {string} does not contain a letter {letter}")
# Out:
# Enter a string hello mommy
# Enter a letter l
# The string hello mommy contain a letter l and the index is 2

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
l1 = [0, 1, 1, 1, 0, 1, 0]
i = 0
zero = False
while not zero and i < len(l1):
    if l1[i] == 0:
        l1[i] = 1
        zero = True
    i += 1
if zero:
    print(l1)
else:
    print("There is no zero in entries")
# Out:
# [1, 1, 1, 1, 0, 1, 0]

# %%
l1 = [1,1,1,1,1,1,1]
i = 0
zero = False
while not zero and i < len(l1):
    if l1[i] == 0:
        l1[i] = 1
        zero = True
    i += 1
if zero:
    print(l1)
else:
    print("There is no zero in entries")
# Out:
# There is no zero in entries
