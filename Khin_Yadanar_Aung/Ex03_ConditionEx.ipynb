# %% [markdown]
# <a href="https://colab.research.google.com/github/myothida/PythonProgramming/blob/main/Ex3_ConditionEx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program that asks the user to enter a length in centimeters. If the user enters a negative length, the program should tell the user that the entry is invalid. Otherwise, the program should convert the length to inches and print out the result. There are 2.54 centimeters in an inch.

# %%
len_centi = int(input("Enter a length in centimeters"))
if(len_centi<=0):
    print("The entry is invalid, please enter a positive number")
else:
    len_inch = len_centi / 2.54
    print(f"The length of {len_centi} centimeters in inches is {len_inch} inches")
# Out:
# The length of 60 centimeters in inches is 23.62204724409449 inches

# %% [markdown]
# Ask the user to enter a temperature in Celsius. The program should print a message based on the temperature:
#
# *   If the temperature is less than -273.15, print that the temperature is invalid because it is below absolute zero.
# *   If it is exactly -273.15, print that the temperature is absolute 0.
# *   If the temperature is between -273.15 and 0, print that the temperature is below freezing.
# *   If it is 0, print that the temperature is at the freezing point.
# *   If it is between 0 and 100, print that the temperature is in the normal range.
# *   If it is 100, print that the temperature is at the boiling point.
# *   If it is above 100, print that the temperature is above the boiling point.

# %%
temp_celsius = float(input("Enter temperature in Celsius"))
if(temp_celsius<-273.15):
    print(f"The temperature {temp_celsius} is invalid, please enter a temperature above -273.15 Celsius")
elif(temp_celsius==-273.15):
    print(f"The temperature {temp_celsius} is absolute 0.")
elif(temp_celsius<0):
    print(f"The temperature {temp_celsius} is below freezing point.")
elif(temp_celsius==0):
    print(f"The temperature {temp_celsius} is at freezing point.")
elif(temp_celsius<100):
    print(f"The temperature {temp_celsius} is in normal range.")
elif(temp_celsius==100):
    print(f"The temperature {temp_celsius} is at the boiling point.")
else:
    print(f"The temperature {temp_celsius} is above the boiling point.")
# Out:
# The temperature 130.0 is above the boiling point.

# %% [markdown]
# Write a program that asks the user how many credits they have taken. If they have taken 23 or less, print that the student is a freshman. If they have taken between 24 and 53, print that they are a sophomore. The range for juniors is 54 to 83, and for seniors it is 84 and over.

# %%
credit = int(input("Enter your credits taken"))
if(credit<23):
    print("The Student is a freshman")
elif(credit<53):
    print("The Student is a sophomore")
elif(credit<83):
    print("The Student is a junior")
else:
    print("The Student is a senior")
# Out:
# The Student is a senior
